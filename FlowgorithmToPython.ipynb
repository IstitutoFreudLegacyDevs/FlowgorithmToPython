# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">
# <div style="text-align: center;">
#   <img src="https://i.postimg.cc/W3LSfKnV/FILIGRANA.png" height="280px" width="280px">
# </div>
# <h1 style="text-align: center; font-size: 28px; font-weight: 600; color: #24292F;">Benvenut*!</h1>
# <p style="text-align: center; font-size: 18px; color: #586069; line-height: 1.6; max-width: 600px; margin: 20px auto;">
#   Esplora i nostri progetti in Flowgorithm tradotti in Python, prendi spunto dalle soluzioni proposte e scopri nuove idee!
# </p>
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">
# </br>
# </br>

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">

# %% [markdown]
# <h1 style="text-align: center; font-size: 28px; font-weight: 600; color: #24292F;">Calcolo Area Poligoni</h1>

# %% [markdown]
# <p style="text-align: center; font-size: 14px; color: #586069; line-height: 1.6; max-width: 600px; margin: 20px auto;">
#   Calcola l'area di un poligono attraverso questo sistema!
# </p>

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">

# %% [markdown]
# ![1 - AreaPoligoni.PNG](attachment:189e9db2-ddbc-4188-a49c-b99410bcfb60.PNG)

# %%
print("Ciao, sono un calcolatore di aree, digita q per il quadrato, t per il triangolo ")
scelta = input()
if scelta == "q":
    print("Calcolo l'area del quadrato, dammi il lato")
    l = float(input())
    while l <= 0:
        print("Scemo dammi un lato positivo!")
        l = float(input())
    a = l ** 2
else:
    if scelta == "t":
        print("Calcolo l'area del triangolo, dammi il lato")
        b = float(input())
        while b <= 0:
            print("Scemo dammi una base positivo!")
            b = float(input())
        print("dammi l'altezza")
        h = float(input())
        while h <= 0:
            print("Scemo dammi un'altezza positiva!")
            h = float(input())
        a = b * h / 2
    else:
        print("hai scelto male! ritenta")
        a = 0
print("l'area della figura e:")
print(a)
# Out:
# Ciao, sono un calcolatore di aree, digita q per il quadrato, t per il triangolo
#  q
# Calcolo l'area del quadrato, dammi il lato
#  4
# l'area della figura e:
# 16.0

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">

# %% [markdown]
# <h1 style="text-align: center; font-size: 28px; font-weight: 600; color: #24292F;">PushButton</h1>

# %% [markdown]
# <p style="text-align: center; font-size: 14px; color: #586069; line-height: 1.6; max-width: 600px; margin: 20px auto;">
#   Verifica se il PUSHBUTTON del nostro Arduino è premuto in modo tale da accendere il led!
# </p>

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">

# %% [markdown]
# ![pushbutton1.PNG](attachment:9f5e78b6-594b-4bf0-b6ec-97ef9feb5f7c.PNG)

# %% [markdown]
# ![push2.PNG](attachment:60d449d2-490d-42bd-8644-88e474a6238d.PNG)

# %%
ledstate = False
buttonstate = False
print("A quale PIN vuoi attaccare il led?")
lED = int(input())
print("Seleziona la modalità del PIN, seleziona TRUE per OUTPUT")
pinmode1 = (input().lower() == 'true')
print("A quale PIN vuoi attaccare il pushbutton?")
pushbutton = int(input())
print("A quale modalità del PIN del pushbutton, seleziona TRUE per OUTPUT")
pinmode1 = (input().lower() == 'true')

# DICHIARAZIONI PER RICHIESTA MASSIMA DI 3 VOLTE D'INSERIMENTO INPUT
volteinputchiesto = 0
voltemassimeperrichiestainput = 3

while volteinputchiesto < voltemassimeperrichiestainput:
    print("Digita TRUE se il pushbutton è schiacciato")
    buttonstate = (input().lower() == 'true')
    
    if buttonstate == True:
        ledstate = True
        print(ledstate)
    else:
        ledstate = False
        print(ledstate)
    
    volteinputchiesto += 1

# DOPO TRE RICHIESTE ESCE DAL CICLO
if volteinputchiesto >= voltemassimeperrichiestainput:
    print("")
# Out:
# A quale PIN vuoi attaccare il led?
#  2
# Seleziona la modalità del PIN, seleziona TRUE per OUTPUT
#  TRUE
# A quale PIN vuoi attaccare il pushbutton?
#  2
# A quale modalità del PIN del pushbutton, seleziona TRUE per OUTPUT
#  true
# Digita TRUE se il pushbutton è schiacciato
#  true
# True
# Digita TRUE se il pushbutton è schiacciato
#  true
# True
# Digita TRUE se il pushbutton è schiacciato
#  true
# True

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">

# %% [markdown]
# <h1 style="text-align: center; font-size: 28px; font-weight: 600; color: #24292F;">BlinkingLed</h1>

# %% [markdown]
# <p style="text-align: center; font-size: 14px; color: #586069; line-height: 1.6; max-width: 600px; margin: 20px auto;">
#   Verifica se il led si accende/spegne come previsto dal sistema!
# </p>

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">

# %% [markdown]
# ![3 - BlinkingLed.PNG](attachment:36993602-41ce-4747-8610-a40c05aef8c3.PNG)

# %%
ledstate = False
print("Inserisci il pin dove attaccare il led")
lED = int(input())
print("Digita TRUE per modalità INPUT o FALSE per l'OUTPUT")
pinmode = (input().lower() == 'true')

# DICHIARAZIONI PER PRINTARE ledstate MASSIMO 6 VOLTE
printcount = 0
printmassimi = 6

while printcount < printmassimi:
    ledstate = True
    print(ledstate)
    ledstate = False
    print(ledstate)
    printcount += 1

# DOPO 6 PRINT ESCE DAL CICLO
if printcount >= printmassimi:
    print("")
# Out:
# Inserisci il pin dove attaccare il led
#  3
# Digita TRUE per modalità INPUT o FALSE per l'OUTPUT
#  true
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">

# %% [markdown]
# <h1 style="text-align: center; font-size: 28px; font-weight: 600; color: #24292F;">Sasso, Carta, Forbice</h1>

# %% [markdown]
# <p style="text-align: center; font-size: 14px; color: #586069; line-height: 1.6; max-width: 600px; margin: 20px auto;">
#   Gioca a Sasso/Carta/Forbice con il nostro sistema!
# </p>

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">

# %% [markdown]
# ![carta1.PNG](attachment:27eab1b9-ed96-4c5a-b02e-7157c857715d.PNG)

# %% [markdown]
# ![carta2.PNG](attachment:93aadbb5-a1f8-445d-8dea-394c00cc6228.PNG)

# %% [markdown]
# ![carta3.PNG](attachment:f6f5816d-c295-4aba-ba22-a94d59110e86.PNG)

# %%
import random
random.seed()   #Prepare random number generator

print("Scegli fra Carta, Forbice e Sasso")
scelta = input()
while scelta != "carta" and scelta != "forbice" and scelta != "sasso" and scelta != "esci":
    print("Input invalido")
    scelta = input()
while scelta != "esci":
    numero = int(random.random() * 3)
    if numero == 0:
        computer = "carta"
    else:
        if numero == 1:
            computer = "forbice"
        else:
            computer = "sasso"
    if scelta == "carta" and computer == "sasso" or scelta == "forbice" and computer == "carta" or scelta == "sasso" and computer == "forbice":
        print(computer)
        print("Hai vinto!")
    else:
        if scelta == "carta" and computer == "carta" or scelta == "forbice" and computer == "forbice" or scelta == "sasso" and computer == "sasso":
            print(computer)
            print("Hai pareggiato!")
        else:
            print(computer)
            print("Hai perso!")
    scelta = input()
    while scelta != "carta" and scelta != "forbice" and scelta != "sasso" and scelta != "esci":
        print("Input invalido")
        scelta = input()
# Out:
# Scegli fra Carta, Forbice e Sasso
#  carta
# carta
# Hai pareggiato!
#  sasso
# sasso
# Hai pareggiato!
#  forbice
# carta
# Hai vinto!
#  forbice
# carta
# Hai vinto!
#  esci

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">

# %% [markdown]
# <h1 style="text-align: center; font-size: 28px; font-weight: 600; color: #24292F;">Check Number</h1>

# %% [markdown]
# <p style="text-align: center; font-size: 14px; color: #586069; line-height: 1.6; max-width: 600px; margin: 20px auto;">
#   Verifica se un numero è positivo/negativo oppure pari o dispari!
# </p>

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">

# %% [markdown]
# ![5 - CheckNumber.PNG](attachment:f07324cf-98f8-46d7-b3d4-03d1e5e59b45.PNG)

# %%
print("Inserisci un numero")
numero = int(input())
if numero > 0:
    print("Il numero è positivo, maggiore di zero!")
else:
    if numero == 0:
        print("Il numero è zero!")
    else:
        print("Il numero è negativo, minore di zero!")
if numero % 2 == 0:
    print("Il numero è pari!")
else:
    print("Il numero è dispari!")
# Out:
# Inserisci un numero
#  55
# Il numero è positivo, maggiore di zero!
# Il numero è dispari!

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">

# %% [markdown]
# <h1 style="text-align: center; font-size: 28px; font-weight: 600; color: #24292F;">Fattoriali Di Una Lista</h1>

# %% [markdown]
# <p style="text-align: center; font-size: 14px; color: #586069; line-height: 1.6; max-width: 600px; margin: 20px auto;">
#   Richiedi il fattoriale di una lista di numeri da te immessa!
# </p>

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">

# %% [markdown]
# ![6 - FattorialiLista.PNG](attachment:f71a83f9-4367-44cf-b626-38467231d9c8.PNG)

# %%
lista = [0] * (3)
fattoriali = [0] * (3)

print("dammi una lista di valori dei quali vuoi il fattoriale")
for i in range(0, 2 + 1, 1):
    lista[i] = int(input())
for i in range(0, 2 + 1, 1):
    risultato = 1
    for k in range(1, lista[i] + 1, 1):
        risultato = risultato * k
    fattoriali[i] = risultato
    print(fattoriali[i])
# Out:
# dammi una lista di valori dei quali vuoi il fattoriale
#  5
#  4
#  3
# 120
# 24
# 6

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">

# %% [markdown]
# <h1 style="text-align: center; font-size: 28px; font-weight: 600; color: #24292F;">Lettura Potenziometro</h1>

# %% [markdown]
# <p style="text-align: center; font-size: 14px; color: #586069; line-height: 1.6; max-width: 600px; margin: 20px auto;">
#   Verifica la lettura del potenziometro in base a quanto è "girato"!
# </p>

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">

# %% [markdown]
# ![7 - LetturaPotenziometro.PNG](attachment:37f09b50-6c6d-4837-9b73-c4fe7721ccd3.PNG)

# %%
print("A quale PIN vuoi attaccare il potenziometro")
analogPIN = input()
print("Digita TRUE per modalità OUTPUT, FALSE per INPUT")
pinmode = (input().lower() == 'true')

# DICHIARAZIONI DI RICHIESTA INPUT MAX 3 VOLTE
chiestocount = 0
maxvoltechiesto = 3

while chiestocount < maxvoltechiesto:
    print("Digita il numero di livelli tra 10 e 1023")
    livelli = int(input())
    print("La lettura del potenziometro è:")
    print(livelli)
    
    chiestocount += 1

# DOPO 3 VOLTE ESCE DAL CICLO
if chiestocount >= maxvoltechiesto:
    print("")
# Out:
# A quale PIN vuoi attaccare il potenziometro
#  5
# Digita TRUE per modalità OUTPUT, FALSE per INPUT
#  TRUE
# Digita il numero di livelli tra 10 e 1023
#  1023
# La lettura del potenziometro è:
# 1023
# Digita il numero di livelli tra 10 e 1023
#  5
# La lettura del potenziometro è:
# 5
# Digita il numero di livelli tra 10 e 1023
#  7
# La lettura del potenziometro è:
# 7

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">

# %% [markdown]
# <h1 style="text-align: center; font-size: 28px; font-weight: 600; color: #24292F;">Striscia Led</h1>

# %% [markdown]
# <p style="text-align: center; font-size: 14px; color: #586069; line-height: 1.6; max-width: 600px; margin: 20px auto;">
#   Accendi una striscia di led in modo graduale "sul nostro Arduino"!
# </p>

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">

# %% [markdown]
# ![STRISCIA1.PNG](attachment:ec8d36cd-8a07-40b6-903f-5d08da83529f.PNG)

# %% [markdown]
# ![STRISCIA2.PNG](attachment:02a7d098-b095-4787-bf68-c46e144722c9.PNG)

# %%
ledPins = [0] * (5)
ledStates = [False] * (5)
pinmode = [False] * (5)

ledcount = 5
for i in range(0, ledcount - 1 + 1, 1):
    print("Dimmi i PIN al quale attaccare i LED")
    ledPins[i] = int(input())
    ledStates[i] = False
for i in range(0, ledcount - 1 + 1, 1):
    print("Dimmi la modalità dei PIN")
    pinmode[i] = (input().lower() == 'true')

print("Dimmi il livello corrispondente del potenziometro")
livelli = int(input())
ledlevel = float(livelli * ledcount) / 1023
print("Il livello è: ")
print(ledlevel)
for thisLed in range(0, ledcount - 1 + 1, 1):
    if thisLed < ledlevel:
        ledStates[thisLed] = True
    else:
        ledStates[thisLed] = False
    print(ledStates[thisLed])
# Out:
# Dimmi i PIN al quale attaccare i LED
#  1
# Dimmi i PIN al quale attaccare i LED
#  2
# Dimmi i PIN al quale attaccare i LED
#  3
# Dimmi i PIN al quale attaccare i LED
#  4
# Dimmi i PIN al quale attaccare i LED
#  5
# Dimmi la modalità dei PIN
#  6
# Dimmi la modalità dei PIN
#  7
# Dimmi la modalità dei PIN
#  8
# Dimmi la modalità dei PIN
#  9
# Dimmi la modalità dei PIN
#  10
# Dimmi il livello corrispondente del potenziometro
#  5
# Il livello è:
# 0.024437927663734114
# True
# False
# False
# False
# False

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">

# %% [markdown]
# <h1 style="text-align: center; font-size: 28px; font-weight: 600; color: #24292F;">Risultato Vettore - Fixed</h1>

# %% [markdown]
# <p style="text-align: center; font-size: 14px; color: #586069; line-height: 1.6; max-width: 600px; margin: 20px auto;">
#   Verifica il fattoriale di un solo numero da te immesso!
# </p>

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">

# %% [markdown]
# ![9 - RisultatoVettore.PNG](attachment:8cb9ee2e-e3c3-40ad-9994-d4829fcb3df8.PNG)

# %%
risultato = 1
print("Inserisci il numero di cui desideri sapere il fattoriale")
numero = int(input())
for i in range(1, numero + 1, 1):
    risultato = risultato * i
print("Il fattoriale del numero è:")
print(risultato)
# Out:
# Inserisci il numero di cui desideri sapere il fattoriale
#  9
# Il fattoriale del numero è:
# 362880

# %% [markdown]
# <hr style="border: none; border-top: 1px solid #E1E4E8; width: 60%; margin: 30px auto;">

# %% [markdown]
# <p style="text-align: center; font-size: 14px; color: #586069; line-height: 1.6; max-width: 600px; margin: 20px auto;">
#   Made By <a href="https://github.com/IstitutoFreudLegacyDevs" target = "_blank" style="text-decoration: none; color: black;" onmouseover="this.style.color='rgb(117, 117, 117)'" onmouseout="this.style.color='black'">LD Network</a>
# </p>
